# %% [markdown]
# # Riemann MCMC (simplified MMALA)

# %% [markdown]
# First, let's import `REBOUND`. This version of rebound can integrate the second order variational equations with IAS15, a high accuracy non-symplectic integrator. The only thing that is not yet implemented is varying the mass. Currently the variational particles have the same mass as their real counterparts.
#
# Note that I'll do some refactoring in the code some time soon to change several variable names. Right now, whenever the word *MEGNO* appears, replace it with *variational*.

# %% [markdown]
# We also import numpy, scipy (for multidimensional normal distributions) and matplotlib (for plotting).

# %%
# %matplotlib inline
import rebound as r
r.reset()
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
r.status()
# Out:
# ---------------------------------
# Rebound version:     	1.1.0
# Build on:            	Jul  5 2015 12:26:39
# Number of particles: 	0
# Simulation time:     	0.000000
# ---------------------------------

# %% [markdown]
# ## Helper function to setup simulations
# The following functions setup particles according to a given set of parameters. We denote model parameters as $\theta$ (theta).
#
# The fake observations span over a time of 10 years and have a precision of 1 m/s.

# %%
CU2MS = 29785.891  # Convert year/(2pi) to m/s

def particleSetupDict(thetap):
    # Defaults
    a = 1.; anom = 0.; omega = -np.pi/2.; m = 1e-3;
    for i, name in enumerate(theta_names):
        if name == "a":
            a = thetap[i]
        if name == "anom":
            anom = thetap[i]
        if name == "omega":
            omega = thetap[i]
        if name == "m": # Not yet implemented!!
            m = thetap[i]  
    return r.Particle(primary=r.particles[0],m=m,a=a,e=0.,anom=anom,omega=omega)

def getRV(thetar,times=None):
    if times is None:
        times = data_t
    r.reset()
    r.add(m=1.)
    r.add(particleSetupDict(thetar))
    r.move_to_com()
    ps = r.particles
    rvs = np.zeros(len(times))
    for i,t in enumerate(times):
        r.integrate(t)
        rvs[i] = ps[0].vx*CU2MS
    return rvs

def generateObs(thetao, data_N):
    global data_t, data_rv, data_err, N_param
    N_param = len(thetao)
    tmax = 0.01*2.*np.pi
    data_t = np.sort(np.random.uniform(0.,tmax,data_N)).copy()
    error_scale = 1.
    data_rv = getRV(thetao,times=data_t)+np.random.normal(0.,error_scale,data_N)
    data_err = np.full(data_N,error_scale)

# %% [markdown]
# ## Test observation
# Let's run the `generateObs()` routine once, just to see what we are dealing with.

# %%
theta_names  = ["m"]
theta_test   =  [1e-3]
generateObs(theta_test,data_N=30)
fig1 = plt.figure(figsize=(12,5))
times = np.linspace(data_t[0],data_t[-1],500)
plt.plot(times, getRV(theta_test,times=times), color="b");
plt.ylabel("radial velocity [m/s]"); plt.xlabel("time [year/(2$\pi$)]")
plt.errorbar(data_t, data_rv, yerr=data_err, fmt="bo")
plt.grid()

# %% [markdown]
# ## Helper functions
# Two more helper functions. These find the right location in the particle array for the a given index for the first order variational equations and for two given indicies for the second order variational equations.

# %%
N = 2 # Two particles
def varid2(l,k):
    if k>l:
        raise Exception("error")
    if l>=N_param:
        raise Exception("error")
    var = l*(l+1)/2+k
    return var*N+N+N*N_param
def varid1(l):
    if l>=N_param:
        raise Exception("error")
    return N*l+N

# %% [markdown]
# ## Simulation
# This is the work-horse function which sets up and runs a simulation using the parameters `thetas`. It returns logp and its first two derivatives with respect to `thetas`.
#
# Currently, all the variational equations are calculate with the same initial `delta`. This is not good and should be changed. Something like `delta` times the current value might make sense. But one has to make sure there are no issues due to limited floating point precision.

# %%
def com(varoffset):
    ps = r.particles
    m = 0.
    x = 0.
    y = 0.
    z = 0.
    vx = 0.
    vy = 0.
    vz = 0.
    for i in range(N):
        m  += (ps[i].m+ps[i+varoffset].m)
        x  += (ps[i].x+ps[i+varoffset].x)*(ps[i].m+ps[i+varoffset].m)
        y  += (ps[i].y+ps[i+varoffset].y)*(ps[i].m+ps[i+varoffset].m)
        z  += (ps[i].z+ps[i+varoffset].z)*(ps[i].m+ps[i+varoffset].m)
        vx += (ps[i].vx+ps[i+varoffset].vx)*(ps[i].m+ps[i+varoffset].m)
        vy += (ps[i].vy+ps[i+varoffset].vy)*(ps[i].m+ps[i+varoffset].m)
        vz += (ps[i].vz+ps[i+varoffset].vz)*(ps[i].m+ps[i+varoffset].m)
    if m>0.:
        x /= m
        y /= m
        z /= m
        vx /= m
        vy /= m
        vz /= m
    return r.Particle(m=m, x=x, y=y, z=z, vx=vx, vy=vy, vz=vz)

def simulation(thetas):
    r.reset()
    r.N_megnopp = N_param 
    r.add(m=1.)
    op = particleSetupDict(thetas)
    r.add(op)
    r.move_to_com()
    N = r.N
    r.init_megno(0.)
    ps = r.particles
    
    delta = 1e-5
    # First order
    for l in range(N_param):
        thetas2 = thetas.copy()
        thetas2[l] += delta/2.
        mp = particleSetupDict(thetas2)
        thetas2 = thetas.copy()
        thetas2[l] -= delta/2.
        mm = particleSetupDict(thetas2)

        vari = varid1(l)+1
        ps[vari].m  = (mp.m  - mm.m  )
        ps[vari].x  = (mp.x  - mm.x  )
        ps[vari].y  = (mp.y  - mm.y  )
        ps[vari].z  = (mp.z  - mm.z  )
        ps[vari].vx = (mp.vx - mm.vx )
        ps[vari].vy = (mp.vy - mm.vy )
        ps[vari].vz = (mp.vz - mm.vz )
        
        c = com(varid1(l))
        print ps[vari].vx/ps[1].vx
        
        ps[vari].x  -= c.x
        ps[vari].y  -= c.y
        ps[vari].z  -= c.z
        ps[vari].vx -= c.vx
        ps[vari].vy -= c.vy
        ps[vari].vz -= c.vz
        
        ps[vari-1].x  -= c.x
        ps[vari-1].y  -= c.y
        ps[vari-1].z  -= c.z
        ps[vari-1].vx -= c.vx
        ps[vari-1].vy -= c.vy
        ps[vari-1].vz -= c.vz
        
    # Second order
    for l in range(N_param):
        for k in range(l+1):
            fac = 2.
            thetas2 = thetas.copy()
            thetas2[l] += delta/fac
            thetas2[k] += delta/fac
            mpp = particleSetupDict(thetas2)
            thetas2 = thetas.copy()
            thetas2[l] += delta/fac
            thetas2[k] -= delta/fac
            mpm = particleSetupDict(thetas2)
            thetas2 = thetas.copy()
            thetas2[l] -= delta/fac
            thetas2[k] += delta/fac
            mmp = particleSetupDict(thetas2)
            thetas2 = thetas.copy()
            thetas2[l] -= delta/fac
            thetas2[k] -= delta/fac
            mmm = particleSetupDict(thetas2)
            
            vari2 = varid2(l,k)+1
            ps[vari2].m  = mpp.m  - mpm.m  - mmp.m  + mmm.m
            ps[vari2].x  = mpp.x  - mpm.x  - mmp.x  + mmm.x
            ps[vari2].y  = mpp.y  - mpm.y  - mmp.y  + mmm.y 
            ps[vari2].z  = mpp.z  - mpm.z  - mmp.z  + mmm.z 
            ps[vari2].vx = mpp.vx - mpm.vx - mmp.vx + mmm.vx
            ps[vari2].vy = mpp.vy - mpm.vy - mmp.vy + mmm.vy
            ps[vari2].vz = mpp.vz - mpm.vz - mmp.vz + mmm.vz
    
    
    ##################################################################
    # INTEGRATION
    logps   = 0.
    logp_d  = np.zeros(N_param)
    logp_d2 = np.zeros((N_param*(N_param+1)/2,2))
    for i,t in enumerate(data_t):
        r.integrate(t)
        dv = ps[0].vx*CU2MS-data_rv[i]
        derri = 1./(2.*(data_err[i]**2))
        logps  += -dv**2*derri
        for k in range(N_param):
            vari1 = varid1(k)
            logp_d[k] += -2.*ps[vari1].vx*CU2MS/delta * dv *derri
            print t, vari1, ps[vari1].vx, ps[0].vx
        _id = 0
        for l in range(N_param):
            for k in range(l+1):
                vari2 = varid2(l,k)
                vari1l = varid1(l)
                vari1k = varid1(k)
                logp_d2[_id][0] += -2.*(ps[vari1l].vx*CU2MS * ps[vari1k].vx*CU2MS)/(delta*delta)*derri
                # Expectation value would remove next line, still a valid metric, but less useful
                logp_d2[_id][1] += -2.*(ps[vari2].vx*CU2MS * dv)/(delta*delta)*derri
                _id += 1
    
    logp_d2m = np.zeros((N_param,N_param))
    _id = 0
    for l in range(N_param):
        for k in range(l+1):
            fdd = logp_d2[_id][0] + logp_d2[_id][1]
            logp_d2m[l,k] = fdd
            logp_d2m[k,l] = fdd
            _id +=1
    
    return logps, logp_d, logp_d2m, 1.23

# %%
Ntest = 20
ms = np.linspace(0.5e-3,2e-3,Ntest)
ms = np.linspace(3,5,Ntest)
thetas = np.array([[m] for m in ms])
theta_names=["a"]
results = np.array(map(simulation,thetas))
directgrad = np.zeros(Ntest)
for i in range(1,Ntest-1):
    directgrad[i] = (results[i+1,0]-results[i-1,0])/(ms[i+1]-ms[i-1])
# Out:
# -1.66833333336e-06
# 0.00098623787115 2 9.61769562731e-10 -0.000577061799977
# 0.00174901294949 2 9.61769302354e-10 -0.000577061777658
# 0.00387502383268 2 9.61767810167e-10 -0.000577061649757
# 0.00577807713129 2 9.61765517574e-10 -0.000577061453249
# 0.00818381781605 2 9.61761325756e-10 -0.00057706109395
# 0.0157643938677 2 9.61738669719e-10 -0.000577059152002
# 0.02126406961 2 9.61713255283e-10 -0.000577056973618
# 0.0273920025634 2 9.61676045469e-10 -0.000577053784195
# 0.0289952100974 2 9.61664763735e-10 -0.000577052817185
# 0.0303798802141 2 9.6165450354e-10 -0.000577051937736
# 0.0304378364538 2 9.61654063659e-10 -0.000577051900032
# 0.0326697428031 2 9.61636485962e-10 -0.000577050393364
# 0.0330165269611 2 9.61633643217e-10 -0.000577050149699
# 0.0331119760783 2 9.6163285551e-10 -0.000577050082181
# 0.034197593264 2 9.61623736298e-10 -0.000577049300529
# 0.0352568058035 2 9.61614555376e-10 -0.000577048513588
# 0.03548833314 2 9.61612511276e-10 -0.000577048338378
# 0.0360910595981 2 9.61607127199e-10 -0.000577047876883
# 0.0370670444036 2 9.61598216571e-10 -0.000577047113109
# 0.0376126205325 2 9.61593131931e-10 -0.00057704667728
# 0.0408111963397 2 9.61561827459e-10 -0.000577043994017
# 0.0413432204726 2 9.61556372854e-10 -0.000577043526476
# 0.0441659732083 2 9.61526250704e-10 -0.000577040944552
# 0.0474196757544 2 9.61489062582e-10 -0.000577037756963
# 0.0503548500419 2 9.61453248227e-10 -0.000577034687123
# 0.0509408299031 2 9.61445840751e-10 -0.000577034052187
# 0.0542027535475 2 9.61403039918e-10 -0.000577030383491
# 0.0561625165703 2 9.61376048217e-10 -0.000577028069879
# 0.0588557321935 2 9.61337390979e-10 -0.000577024756344
# 0.0606304601393 2 9.61310927852e-10 -0.000577022488033
# -1.61177966114e-06
# 0.00098623787115 2 9.132828455e-10 -0.000567196769788
# 0.00174901294949 2 9.1328262255e-10 -0.000567196750008
# 0.00387502383268 2 9.13281344859e-10 -0.000567196636649
# 0.00577807713129 2 9.13279381816e-10 -0.000567196462484
# 0.00818381781605 2 9.13275792554e-10 -0.000567196144038
# 0.0157643938677 2 9.13256393219e-10 -0.000567194422893
# 0.02126406961 2 9.13234631989e-10 -0.000567192492194
# 0.0273920025634 2 9.13202770902e-10 -0.000567189665413
# 0.0289952100974 2 9.1319311086e-10 -0.000567188808353
# 0.0303798802141 2 9.13184325514e-10 -0.000567188028898
# 0.0304378364538 2 9.13183948863e-10 -0.000567187995481
# 0.0326697428031 2 9.13168897867e-10 -0.000567186660123
# 0.0330165269611 2 9.13166463751e-10 -0.000567186444162
# 0.0331119760783 2 9.13165789273e-10 -0.000567186384321
# 0.034197593264 2 9.13157980898e-10 -0.000567185691544
# 0.0352568058035 2 9.13150119682e-10 -0.000567184994079
# 0.03548833314 2 9.13148369411e-10 -0.000567184838791
# 0.0360910595981 2 9.13143759264e-10 -0.000567184429768
# 0.0370670444036 2 9.13136129489e-10 -0.000567183752836
# 0.0376126205325 2 9.13131775737e-10 -0.000567183366561
# 0.0408111963397 2 9.13104971099e-10 -0.000567180988388
# 0.0413432204726 2 9.13100300561e-10 -0.000567180574006
# 0.0441659732083 2 9.13074508285e-10 -0.000567178285648
# 0.0474196757544 2 9.13042665718e-10 -0.00056717546049
# 0.0503548500419 2 9.13011999438e-10 -0.000567172739691
# 0.0509408299031 2 9.13005656735e-10 -0.000567172176948
# 0.0542027535475 2 9.12969008221e-10 -0.000567168925383
# 0.0561625165703 2 9.1294589638e-10 -0.000567166874829
# 0.0588557321935 2 9.12912795828e-10 -0.000567163938042
# 0.0606304601393 2 9.12890136568e-10 -0.000567161927637
# -1.55893442617e-06
# 0.00098623787115 2 8.68737502169e-10 -0.000557820971671
# 0.00174901294949 2 8.68737310278e-10 -0.000557820954068
# 0.00387502383268 2 8.68736210574e-10 -0.000557820853193
# 0.00577807713129 2 8.6873452099e-10 -0.000557820698209
# 0.00818381781605 2 8.68731431726e-10 -0.000557820414833
# 0.0157643938677 2 8.68714734794e-10 -0.000557818883234
# 0.02126406961 2 8.68696004983e-10 -0.000557817165158
# 0.0273920025634 2 8.68668582256e-10 -0.000557814649683
# 0.0289952100974 2 8.6866026789e-10 -0.000557813887009
# 0.0303798802141 2 8.68652706371e-10 -0.000557813193394
# 0.0304378364538 2 8.68652382189e-10 -0.000557813163657
# 0.0326697428031 2 8.68639427844e-10 -0.000557811975358
# 0.0330165269611 2 8.68637332807e-10 -0.000557811783181
# 0.0331119760783 2 8.68636752286e-10 -0.00055781172993
# 0.034197593264 2 8.68630031641e-10 -0.000557811113447
# 0.0352568058035 2 8.68623265516e-10 -0.000557810492792
# 0.03548833314 2 8.68621759063e-10 -0.000557810354605
# 0.0360910595981 2 8.68617791123e-10 -0.000557809990626
# 0.0370670444036 2 8.68611224197e-10 -0.000557809388243
# 0.0376126205325 2 8.68607476935e-10 -0.000557809044507
# 0.0408111963397 2 8.68584406255e-10 -0.000557806928235
# 0.0413432204726 2 8.68580386335e-10 -0.000557806559488
# 0.0441659732083 2 8.68558186986e-10 -0.000557804523141
# 0.0474196757544 2 8.68530780158e-10 -0.000557802009108
# 0.0503548500419 2 8.6850438575e-10 -0.000557799587942
# 0.0509408299031 2 8.68498926598e-10 -0.000557799087172
# 0.0542027535475 2 8.68467383282e-10 -0.00055779619369
# 0.0561625165703 2 8.68447490952e-10 -0.000557794368957
# 0.0588557321935 2 8.68419001346e-10 -0.000557791755587
# 0.0606304601393 2 8.68399498543e-10 -0.00055778996658
# -1.50944444439e-06
# 0.00098623787115 2 8.27699136725e-10 -0.000548895260979
# 0.00174901294949 2 8.27698970763e-10 -0.000548895245256
# 0.00387502383268 2 8.2769801966e-10 -0.000548895155152
# 0.00577807713129 2 8.27696558387e-10 -0.000548895016715
# 0.00818381781605 2 8.27693886569e-10 -0.000548894763596
# 0.0157643938677 2 8.27679445859e-10 -0.000548893395528
# 0.02126406961 2 8.27663246968e-10 -0.000548891860894
# 0.0273920025634 2 8.2763952981e-10 -0.000548889614
# 0.0289952100974 2 8.27632338943e-10 -0.000548888932758
# 0.0303798802141 2 8.27625799192e-10 -0.0005488883132
# 0.0304378364538 2 8.27625518816e-10 -0.000548888286638
# 0.0326697428031 2 8.27614314957e-10 -0.000548887225216
# 0.0330165269611 2 8.27612503018e-10 -0.000548887053558
# 0.0331119760783 2 8.27612000941e-10 -0.000548887005992
# 0.034197593264 2 8.27606188438e-10 -0.000548886455332
# 0.0352568058035 2 8.27600336601e-10 -0.000548885900944
# 0.03548833314 2 8.2759903371e-10 -0.000548885777512
# 0.0360910595981 2 8.27595601947e-10 -0.000548885452396
# 0.0370670444036 2 8.27589922391e-10 -0.00054888491433
# 0.0376126205325 2 8.27586681485e-10 -0.000548884607295
# 0.0408111963397 2 8.27566728276e-10 -0.00054888271698
# 0.0413432204726 2 8.27563251555e-10 -0.000548882387604
# 0.0441659732083 2 8.27544051931e-10 -0.000548880568679
# 0.0474196757544 2 8.27520348493e-10 -0.000548878323072
# 0.0503548500419 2 8.27497520664e-10 -0.000548876160415
# 0.0509408299031 2 8.27492799187e-10 -0.000548875713113
# 0.0542027535475 2 8.27465518194e-10 -0.000548873128569
# 0.0561625165703 2 8.27448313832e-10 -0.000548871498663
# 0.0588557321935 2 8.27423673901e-10 -0.000548869164324
# 0.0606304601393 2 8.27406806423e-10 -0.00054886756633
# -1.46300000005e-06
# 0.00098623787115 2 7.89793027036e-10 -0.000540384742133
# 0.00174901294949 2 7.89792882847e-10 -0.000540384728039
# 0.00387502383268 2 7.89792056524e-10 -0.000540384647271
# 0.00577807713129 2 7.89790786962e-10 -0.000540384523178
# 0.00818381781605 2 7.89788465674e-10 -0.000540384296285
# 0.0157643938677 2 7.8977591951e-10 -0.000540383069968
# 0.02126406961 2 7.89761845826e-10 -0.000540381694343
# 0.0273920025634 2 7.89741240228e-10 -0.000540379680258
# 0.0289952100974 2 7.89734992763e-10 -0.000540379069601
# 0.0303798802141 2 7.8972931099e-10 -0.000540378514238
# 0.0304378364538 2 7.89729067398e-10 -0.000540378490429
# 0.0326697428031 2 7.89719333421e-10 -0.000540377538984
# 0.0330165269611 2 7.89717759197e-10 -0.000540377385112
# 0.0331119760783 2 7.8971732299e-10 -0.000540377342475
# 0.034197593264 2 7.89712273053e-10 -0.00054037684887
# 0.0352568058035 2 7.89707188943e-10 -0.000540376351925
# 0.03548833314 2 7.89706056983e-10 -0.000540376241282
# 0.0360910595981 2 7.89703075447e-10 -0.000540375949852
# 0.0370670444036 2 7.89698141014e-10 -0.000540375467537
# 0.0376126205325 2 7.89695325296e-10 -0.000540375192315
# 0.0408111963397 2 7.89677989825e-10 -0.000540373497861
# 0.0413432204726 2 7.89674969229e-10 -0.000540373202613
# 0.0441659732083 2 7.89658288474e-10 -0.000540371572152
# 0.0474196757544 2 7.89637694773e-10 -0.000540369559219
# 0.0503548500419 2 7.89617861803e-10 -0.000540367620642
# 0.0509408299031 2 7.89613759751e-10 -0.000540367219685
# 0.0542027535475 2 7.89590057835e-10 -0.000540364902934
# 0.0561625165703 2 7.89575110563e-10 -0.000540363441906
# 0.0588557321935 2 7.89553703211e-10 -0.000540361349434
# 0.0606304601393 2 7.8953904862e-10 -0.000540359917012
# -1.41932835825e-06
# 0.00098623787115 2 7.54694403135e-10 -0.000532258193428
# 0.00174901294949 2 7.54694277329e-10 -0.000532258180753
# 0.00387502383268 2 7.54693556348e-10 -0.000532258108112
# 0.00577807713129 2 7.54692448635e-10 -0.000532257996508
# 0.00818381781605 2 7.54690423273e-10 -0.000532257792449
# 0.0157643938677 2 7.54679476541e-10 -0.000532256689545
# 0.02126406961 2 7.54667197021e-10 -0.000532255452359
# 0.0273920025634 2 7.54649218296e-10 -0.000532253640965
# 0.0289952100974 2 7.54643767278e-10 -0.000532253091763
# 0.0303798802141 2 7.54638809837e-10 -0.00053225259229
# 0.0304378364538 2 7.54638597299e-10 -0.000532252570876
# 0.0326697428031 2 7.5463010424e-10 -0.000532251715182
# 0.0330165269611 2 7.54628730704e-10 -0.000532251576795
# 0.0331119760783 2 7.54628350105e-10 -0.000532251538449
# 0.034197593264 2 7.54623943951e-10 -0.000532251094519
# 0.0352568058035 2 7.54619507978e-10 -0.000532250647585
# 0.03548833314 2 7.54618520325e-10 -0.000532250548076
# 0.0360910595981 2 7.54615918883e-10 -0.000532250285975
# 0.0370670444036 2 7.54611613507e-10 -0.000532249852199
# 0.0376126205325 2 7.54609156745e-10 -0.000532249604674
# 0.0408111963397 2 7.54594031251e-10 -0.000532248080744
# 0.0413432204726 2 7.54591395728e-10 -0.000532247815209
# 0.0441659732083 2 7.54576841482e-10 -0.000532246348833
# 0.0474196757544 2 7.54558873119e-10 -0.000532244538474
# 0.0503548500419 2 7.54541568504e-10 -0.000532242794988
# 0.0509408299031 2 7.54537989391e-10 -0.000532242434382
# 0.0542027535475 2 7.54517309047e-10 -0.00053224035078
# 0.0561625165703 2 7.54504267283e-10 -0.000532239036785
# 0.0588557321935 2 7.54485588981e-10 -0.00053223715489
# 0.0606304601393 2 7.54472802583e-10 -0.000532235866622
# -1.37818840597e-06
# 0.00098623787115 2 7.22120543072e-10 -0.000524487584235
# 0.00174901294949 2 7.22120432863e-10 -0.0005244875728
# 0.00387502383268 2 7.22119801267e-10 -0.000524487507266
# 0.00577807713129 2 7.22118830884e-10 -0.00052448740658
# 0.00818381781605 2 7.2211705662e-10 -0.000524487222483
# 0.0157643938677 2 7.22107467025e-10 -0.000524486227472
# 0.02126406961 2 7.22096709877e-10 -0.000524485111315
# 0.0273920025634 2 7.22080960087e-10 -0.000524483477124
# 0.0289952100974 2 7.22076184866e-10 -0.000524482981649
# 0.0303798802141 2 7.22071842029e-10 -0.000524482531037
# 0.0304378364538 2 7.2207165584e-10 -0.000524482511718
# 0.0326697428031 2 7.22064215718e-10 -0.000524481739733
# 0.0330165269611 2 7.22063012467e-10 -0.000524481614884
# 0.0331119760783 2 7.22062679054e-10 -0.00052448158029
# 0.034197593264 2 7.22058819157e-10 -0.000524481179788
# 0.0352568058035 2 7.22054933138e-10 -0.000524480776575
# 0.03548833314 2 7.2205406793e-10 -0.000524480686801
# 0.0360910595981 2 7.22051789005e-10 -0.000524480450341
# 0.0370670444036 2 7.22048017392e-10 -0.000524480058999
# 0.0376126205325 2 7.22045865209e-10 -0.000524479835689
# 0.0408111963397 2 7.2203261491e-10 -0.000524478460839
# 0.0413432204726 2 7.22030306128e-10 -0.00052447822128
# 0.0441659732083 2 7.22017556254e-10 -0.000524476898354
# 0.0474196757544 2 7.22001815528e-10 -0.000524475265095
# 0.0503548500419 2 7.21986656259e-10 -0.000524473692167
# 0.0509408299031 2 7.21983520867e-10 -0.000524473366838
# 0.0542027535475 2 7.21965404372e-10 -0.000524471487066
# 0.0561625165703 2 7.21953979461e-10 -0.000524470301614
# 0.0588557321935 2 7.21937616799e-10 -0.000524468603817
# 0.0606304601393 2 7.21926415591e-10 -0.000524467441574
# -1.33936619702e-06
# 0.00098623787115 2 6.91824305191e-10 -0.00051704766755
# 0.00174901294949 2 6.9182420828e-10 -0.000517047657203
# 0.00387502383268 2 6.9182365289e-10 -0.000517047597906
# 0.00577807713129 2 6.91822799591e-10 -0.000517047506802
# 0.00818381781605 2 6.91821239404e-10 -0.000517047340225
# 0.0157643938677 2 6.9181280686e-10 -0.000517046439908
# 0.02126406961 2 6.91803347634e-10 -0.000517045429975
# 0.0273920025634 2 6.91789498162e-10 -0.000517043951307
# 0.0289952100974 2 6.91785299102e-10 -0.000517043502985
# 0.0303798802141 2 6.91781480257e-10 -0.000517043095258
# 0.0304378364538 2 6.91781316533e-10 -0.000517043077778
# 0.0326697428031 2 6.9177477411e-10 -0.000517042379262
# 0.0330165269611 2 6.91773716039e-10 -0.000517042266294
# 0.0331119760783 2 6.91773422854e-10 -0.000517042234992
# 0.034197593264 2 6.91770028678e-10 -0.000517041872605
# 0.0352568058035 2 6.91766611533e-10 -0.000517041507766
# 0.03548833314 2 6.91765850717e-10 -0.000517041426535
# 0.0360910595981 2 6.91763846759e-10 -0.000517041212578
# 0.0370670444036 2 6.91760530215e-10 -0.00051704085848
# 0.0376126205325 2 6.91758637706e-10 -0.000517040656422
# 0.0408111963397 2 6.91746986138e-10 -0.000517039412414
# 0.0413432204726 2 6.91744955925e-10 -0.000517039195654
# 0.0441659732083 2 6.91733744401e-10 -0.000517037998628
# 0.0474196757544 2 6.91719902887e-10 -0.000517036520804
# 0.0503548500419 2 6.91706572672e-10 -0.000517035097568
# 0.0509408299031 2 6.91703815583e-10 -0.0005170348032
# 0.0542027535475 2 6.91687884946e-10 -0.000517033102322
# 0.0561625165703 2 6.91677838514e-10 -0.000517032029687
# 0.0588557321935 2 6.91663450095e-10 -0.000517030493466
# 0.0606304601393 2 6.91653600372e-10 -0.000517029441831
# -1.30267123295e-06
# 0.00098623787115 2 6.63588805157e-10 -0.000509915634375
# 0.00174901294949 2 6.63588719634e-10 -0.000509915624987
# 0.00387502383268 2 6.63588229508e-10 -0.000509915571184
# 0.00577807713129 2 6.6358747648e-10 -0.000509915488521
# 0.00818381781605 2 6.63586099631e-10 -0.000509915337378
# 0.0157643938677 2 6.63578657996e-10 -0.000509914520476
# 0.02126406961 2 6.63570310324e-10 -0.000509913604114
# 0.0273920025634 2 6.63558088303e-10 -0.000509912262447
# 0.0289952100974 2 6.63554382674e-10 -0.000509911855663
# 0.0303798802141 2 6.63551012581e-10 -0.000509911485712
# 0.0304378364538 2 6.63550868096e-10 -0.000509911469851
# 0.0326697428031 2 6.63545094471e-10 -0.000509910836053
# 0.0330165269611 2 6.63544160734e-10 -0.000509910733552
# 0.0331119760783 2 6.63543902001e-10 -0.00050991070515
# 0.034197593264 2 6.63540906674e-10 -0.000509910376339
# 0.0352568058035 2 6.63537891076e-10 -0.000509910045302
# 0.03548833314 2 6.63537219664e-10 -0.000509909971598
# 0.0360910595981 2 6.6353545119e-10 -0.000509909777464
# 0.0370670444036 2 6.63532524372e-10 -0.000509909456173
# 0.0376126205325 2 6.63530854251e-10 -0.000509909272836
# 0.0408111963397 2 6.63520571854e-10 -0.000509908144087
# 0.0413432204726 2 6.6351878021e-10 -0.00050990794741
# 0.0441659732083 2 6.63508886146e-10 -0.000509906861289
# 0.0474196757544 2 6.63496671139e-10 -0.000509905520387
# 0.0503548500419 2 6.63484907346e-10 -0.000509904229015
# 0.0509408299031 2 6.63482474241e-10 -0.000509903961921
# 0.0542027535475 2 6.63468415597e-10 -0.00050990241863
# 0.0561625165703 2 6.6345954971e-10 -0.000509901445375
# 0.0588557321935 2 6.63446852057e-10 -0.000509900051486
# 0.0606304601393 2 6.63438159762e-10 -0.000509899097285
# -1.26793333343e-06
# 0.00098623787115 2 6.37223007344e-10 -0.000503070819144
# 0.00174901294949 2 6.37222931615e-10 -0.000503070810603
# 0.00387502383268 2 6.3722249762e-10 -0.000503070761656
# 0.00577807713129 2 6.37221830831e-10 -0.000503070686454
# 0.00818381781605 2 6.37220611663e-10 -0.000503070548954
# 0.0157643938677 2 6.37214022268e-10 -0.000503069805789
# 0.02126406961 2 6.37206630597e-10 -0.000503068972141
# 0.0273920025634 2 6.37195808278e-10 -0.000503067751577
# 0.0289952100974 2 6.37192527028e-10 -0.000503067381511
# 0.0303798802141 2 6.37189542888e-10 -0.000503067044953
# 0.0304378364538 2 6.3718941495e-10 -0.000503067030524
# 0.0326697428031 2 6.37184302537e-10 -0.000503066453935
# 0.0330165269611 2 6.37183475734e-10 -0.000503066360686
# 0.0331119760783 2 6.37183246632e-10 -0.000503066334847
# 0.034197593264 2 6.37180594338e-10 -0.000503066035716
# 0.0352568058035 2 6.37177924095e-10 -0.000503065734559
# 0.03548833314 2 6.37177329574e-10 -0.000503065667508
# 0.0360910595981 2 6.37175763631e-10 -0.000503065490897
# 0.0370670444036 2 6.37173172e-10 -0.000503065198607
# 0.0376126205325 2 6.37171693146e-10 -0.000503065031819
# 0.0408111963397 2 6.37162588316e-10 -0.000503064004954
# 0.0413432204726 2 6.37161001855e-10 -0.00050306382603
# 0.0441659732083 2 6.37152240884e-10 -0.000503062837946
# 0.0474196757544 2 6.37141424769e-10 -0.000503061618078
# 0.0503548500419 2 6.37131008193e-10 -0.000503060443269
# 0.0509408299031 2 6.37128853733e-10 -0.000503060200283
# 0.0542027535475 2 6.37116405115e-10 -0.000503058796295
# 0.0561625165703 2 6.37108554568e-10 -0.000503057910889
# 0.0588557321935 2 6.37097311075e-10 -0.000503056642816
# 0.0606304601393 2 6.37089614238e-10 -0.000503055774744
# -1.23499999986e-06
# 0.00098623787115 2 6.12558057619e-10 -0.000496494447509
# 0.00174901294949 2 6.12557990347e-10 -0.00049649443972
# 0.00387502383268 2 6.12557604823e-10 -0.00049649439508
# 0.00577807713129 2 6.12557012504e-10 -0.000496494326496
# 0.00818381781605 2 6.12555929497e-10 -0.000496494201095
# 0.0157643938677 2 6.12550076032e-10 -0.000496493523325
# 0.02126406961 2 6.12543509893e-10 -0.000496492763035
# 0.0273920025634 2 6.12533896253e-10 -0.000496491649875
# 0.0289952100974 2 6.12530981466e-10 -0.000496491312373
# 0.0303798802141 2 6.12528330606e-10 -0.00049649100543
# 0.0304378364538 2 6.12528216956e-10 -0.000496490992271
# 0.0326697428031 2 6.12523675517e-10 -0.000496490466419
# 0.0330165269611 2 6.12522941055e-10 -0.000496490381376
# 0.0331119760783 2 6.1252273754e-10 -0.000496490357811
# 0.034197593264 2 6.12520381464e-10 -0.000496490085001
# 0.0352568058035 2 6.12518009443e-10 -0.000496489810346
# 0.03548833314 2 6.12517481321e-10 -0.000496489749195
# 0.0360910595981 2 6.12516090268e-10 -0.000496489588125
# 0.0370670444036 2 6.1251378808e-10 -0.000496489321555
# 0.0376126205325 2 6.1251247439e-10 -0.000496489169443
# 0.0408111963397 2 6.12504386419e-10 -0.000496488232938
# 0.0413432204726 2 6.12502977141e-10 -0.000496488069758
# 0.0441659732083 2 6.12495194626e-10 -0.000496487168621
# 0.0474196757544 2 6.12485586492e-10 -0.000496486056095
# 0.0503548500419 2 6.12476333273e-10 -0.000496484984664
# 0.0509408299031 2 6.1247441943e-10 -0.00049648476306
# 0.0542027535475 2 6.12463361113e-10 -0.000496483482616
# 0.0561625165703 2 6.1245638734e-10 -0.000496482675121
# 0.0588557321935 2 6.12446399554e-10 -0.000496481518632
# 0.0606304601393 2 6.12439562322e-10 -0.000496480726947
# -1.20373417722e-06
# 0.00098623787115 2 5.89444214762e-10 -0.000490169419483
# 0.00174901294949 2 5.89444154821e-10 -0.000490169412362
# 0.00387502383268 2 5.89443811312e-10 -0.000490169371555
# 0.00577807713129 2 5.89443283546e-10 -0.000490169308858
# 0.00818381781605 2 5.89442318567e-10 -0.000490169194221
# 0.0157643938677 2 5.89437103026e-10 -0.00049016857463
# 0.02126406961 2 5.89431252479e-10 -0.000490167879602
# 0.0273920025634 2 5.89422686553e-10 -0.000490166861995
# 0.0289952100974 2 5.89420089426e-10 -0.000490166553463
# 0.0303798802141 2 5.89417727461e-10 -0.000490166272869
# 0.0304378364538 2 5.89417626198e-10 -0.000490166260839
# 0.0326697428031 2 5.89413579693e-10 -0.000490165780125
# 0.0330165269611 2 5.89412925274e-10 -0.000490165702382
# 0.0331119760783 2 5.89412743938e-10 -0.00049016568084
# 0.034197593264 2 5.89410644632e-10 -0.000490165431448
# 0.0352568058035 2 5.89408531119e-10 -0.000490165180369
# 0.03548833314 2 5.89408060553e-10 -0.000490165124467
# 0.0360910595981 2 5.89406821099e-10 -0.000490164977223
# 0.0370670444036 2 5.89404769808e-10 -0.000490164733535
# 0.0376126205325 2 5.89403599286e-10 -0.00049016459448
# 0.0408111963397 2 5.89396392757e-10 -0.000490163738363
# 0.0413432204726 2 5.89395137064e-10 -0.00049016358919
# 0.0441659732083 2 5.89388202701e-10 -0.000490162765406
# 0.0474196757544 2 5.89379641676e-10 -0.000490161748378
# 0.0503548500419 2 5.89371396888e-10 -0.000490160768917
# 0.0509408299031 2 5.89369691618e-10 -0.000490160566335
# 0.0542027535475 2 5.89359838453e-10 -0.000490159395802
# 0.0561625165703 2 5.8935362469e-10 -0.000490158657621
# 0.0588557321935 2 5.89344725385e-10 -0.000490157600404
# 0.0606304601393 2 5.89338633283e-10 -0.000490156876675
# -1.17401234554e-06
# 0.00098623787115 2 5.67748270103e-10 -0.000484080122213
# 0.00174901294949 2 5.67748216541e-10 -0.000484080115689
# 0.00387502383268 2 5.67747909584e-10 -0.000484080078301
# 0.00577807713129 2 5.67747437976e-10 -0.000484080020857
# 0.00818381781605 2 5.67746575679e-10 -0.000484079915825
# 0.0157643938677 2 5.67741915112e-10 -0.000484079348147
# 0.02126406961 2 5.67736687108e-10 -0.000484078711352
# 0.0273920025634 2 5.67729032663e-10 -0.000484077779005
# 0.0289952100974 2 5.6772671189e-10 -0.000484077496324
# 0.0303798802141 2 5.67724601257e-10 -0.000484077239239
# 0.0304378364538 2 5.67724510769e-10 -0.000484077228217
# 0.0326697428031 2 5.67720894843e-10 -0.00048407678778
# 0.0330165269611 2 5.67720310059e-10 -0.000484076716551
# 0.0331119760783 2 5.67720148019e-10 -0.000484076696813
# 0.034197593264 2 5.67718272095e-10 -0.000484076468317
# 0.0352568058035 2 5.67716383475e-10 -0.000484076238274
# 0.03548833314 2 5.67715962981e-10 -0.000484076187056
# 0.0360910595981 2 5.67714855414e-10 -0.000484076052149
# 0.0370670444036 2 5.67713022396e-10 -0.000484075828878
# 0.0376126205325 2 5.67711976426e-10 -0.000484075701474
# 0.0408111963397 2 5.67705536726e-10 -0.000484074917087
# 0.0413432204726 2 5.67704414648e-10 -0.000484074780413
# 0.0441659732083 2 5.67698218152e-10 -0.000484074025649
# 0.0474196757544 2 5.67690568083e-10 -0.000484073093833
# 0.0503548500419 2 5.676832006e-10 -0.000484072196436
# 0.0509408299031 2 5.67681676783e-10 -0.000484072010827
# 0.0542027535475 2 5.67672872064e-10 -0.000484070938367
# 0.0561625165703 2 5.6766731949e-10 -0.000484070262035
# 0.0588557321935 2 5.67659367133e-10 -0.000484069293396
# 0.0606304601393 2 5.67653923272e-10 -0.000484068630305
# -1.14572289159e-06
# 0.00098623787115 2 5.47351371647e-10 -0.000478212267726
# 0.00174901294949 2 5.47351323653e-10 -0.000478212261736
# 0.00387502383268 2 5.47351048605e-10 -0.000478212227407
# 0.00577807713129 2 5.47350626022e-10 -0.000478212174663
# 0.00818381781605 2 5.47349853363e-10 -0.000478212078226
# 0.0157643938677 2 5.47345677272e-10 -0.000478211557
# 0.02126406961 2 5.4734099273e-10 -0.000478210972312
# 0.0273920025634 2 5.47334133981e-10 -0.000478210116257
# 0.0289952100974 2 5.47332054457e-10 -0.000478209856707
# 0.0303798802141 2 5.47330163228e-10 -0.000478209620658
# 0.0304378364538 2 5.47330082146e-10 -0.000478209610538
# 0.0326697428031 2 5.47326842103e-10 -0.000478209206141
# 0.0330165269611 2 5.47326318108e-10 -0.00047820914074
# 0.0331119760783 2 5.47326172913e-10 -0.000478209122618
# 0.034197593264 2 5.47324491994e-10 -0.000478208912819
# 0.0352568058035 2 5.473227997e-10 -0.0004782087016
# 0.03548833314 2 5.47322422917e-10 -0.000478208654573
# 0.0360910595981 2 5.47321430484e-10 -0.000478208530705
# 0.0370670444036 2 5.47319788011e-10 -0.000478208325704
# 0.0376126205325 2 5.47318850772e-10 -0.000478208208725
# 0.0408111963397 2 5.47313080491e-10 -0.000478207488523
# 0.0413432204726 2 5.47312075055e-10 -0.000478207363032
# 0.0441659732083 2 5.47306522695e-10 -0.000478206670028
# 0.0474196757544 2 5.47299667864e-10 -0.00047820581446
# 0.0503548500419 2 5.47293066243e-10 -0.000478204990495
# 0.0509408299031 2 5.47291700829e-10 -0.000478204820074
# 0.0542027535475 2 5.47283811374e-10 -0.00047820383537
# 0.0561625165703 2 5.47278835998e-10 -0.00047820321438
# 0.0588557321935 2 5.472717103e-10 -0.000478202325002
# 0.0606304601393 2 5.47266832335e-10 -0.00047820171617
# -1.11876470583e-06
# 0.00098623787115 2 5.28147176006e-10 -0.000472552751797
# 0.00174901294949 2 5.28147132888e-10 -0.000472552746286
# 0.00387502383268 2 5.28146885787e-10 -0.000472552714701
# 0.00577807713129 2 5.28146506141e-10 -0.000472552666175
# 0.00818381781605 2 5.2814581199e-10 -0.000472552577449
# 0.0157643938677 2 5.2814206022e-10 -0.000472552097899
# 0.02126406961 2 5.28137851661e-10 -0.000472551559963
# 0.0273920025634 2 5.28131689809e-10 -0.000472550772357
# 0.0289952100974 2 5.28129821579e-10 -0.00047255053356
# 0.0303798802141 2 5.28128122513e-10 -0.000472550316386
# 0.0304378364538 2 5.28128049669e-10 -0.000472550307075
# 0.0326697428031 2 5.28125138838e-10 -0.000472549935013
# 0.0330165269611 2 5.28124668084e-10 -0.000472549874842
# 0.0331119760783 2 5.28124537642e-10 -0.000472549858169
# 0.034197593264 2 5.28123027516e-10 -0.000472549665145
# 0.0352568058035 2 5.28121507171e-10 -0.000472549470815
# 0.03548833314 2 5.28121168672e-10 -0.000472549427548
# 0.0360910595981 2 5.28120277077e-10 -0.000472549313584
# 0.0370670444036 2 5.28118801491e-10 -0.000472549124975
# 0.0376126205325 2 5.28117959482e-10 -0.00047254901735
# 0.0408111963397 2 5.281127755e-10 -0.000472548354734
# 0.0413432204726 2 5.28111872224e-10 -0.000472548239277
# 0.0441659732083 2 5.28106884022e-10 -0.000472547601686
# 0.0474196757544 2 5.28100725688e-10 -0.000472546814527
# 0.0503548500419 2 5.28094794835e-10 -0.000472546056446
# 0.0509408299031 2 5.28093568156e-10 -0.000472545899651
# 0.0542027535475 2 5.28086480322e-10 -0.000472544993684
# 0.0561625165703 2 5.28082010476e-10 -0.000472544422347
# 0.0588557321935 2 5.28075608795e-10 -0.000472543604083
# 0.0606304601393 2 5.28071226463e-10 -0.000472543043932
# -1.09304597706e-06
# 0.00098623787115 2 5.10040276791e-10 -0.000467089530768
# 0.00174901294949 2 5.10040237958e-10 -0.000467089525688
# 0.00387502383268 2 5.1004001541e-10 -0.000467089496572
# 0.00577807713129 2 5.10039673488e-10 -0.00046708945184
# 0.00818381781605 2 5.10039048311e-10 -0.00046708937005
# 0.0157643938677 2 5.10035669338e-10 -0.000467088927988
# 0.02126406961 2 5.10031878965e-10 -0.000467088432105
# 0.0273920025634 2 5.10026329389e-10 -0.000467087706069
# 0.0289952100974 2 5.10024646796e-10 -0.00046708748594
# 0.0303798802141 2 5.10023116558e-10 -0.000467087285744
# 0.0304378364538 2 5.10023050953e-10 -0.000467087277161
# 0.0326697428031 2 5.10020429357e-10 -0.000467086934184
# 0.0330165269611 2 5.1002000538e-10 -0.000467086878717
# 0.0331119760783 2 5.10019887899e-10 -0.000467086863347
# 0.034197593264 2 5.10018527828e-10 -0.000467086685412
# 0.0352568058035 2 5.10017158552e-10 -0.000467086506274
# 0.03548833314 2 5.10016853688e-10 -0.000467086466389
# 0.0360910595981 2 5.10016050687e-10 -0.000467086361335
# 0.0370670444036 2 5.10014721723e-10 -0.00046708618747
# 0.0376126205325 2 5.1001396338e-10 -0.000467086088258
# 0.0408111963397 2 5.10009294507e-10 -0.000467085477442
# 0.0413432204726 2 5.10008480984e-10 -0.000467085371011
# 0.0441659732083 2 5.10003988436e-10 -0.000467084783262
# 0.0474196757544 2 5.09998442026e-10 -0.000467084057639
# 0.0503548500419 2 5.09993100493e-10 -0.00046708335882
# 0.0509408299031 2 5.09991995703e-10 -0.000467083214283
# 0.0542027535475 2 5.09985612152e-10 -0.000467082379138
# 0.0561625165703 2 5.09981586452e-10 -0.000467081852465
# 0.0588557321935 2 5.09975820874e-10 -0.000467081098168
# 0.0606304601393 2 5.09971873991e-10 -0.000467080581806
# -1.06848314609e-06
# 0.00098623787115 2 4.92944860198e-10 -0.000461811513684
# 0.00174901294949 2 4.92944825141e-10 -0.000461811508992
# 0.00387502383268 2 4.92944624229e-10 -0.000461811482103
# 0.00577807713129 2 4.92944315549e-10 -0.000461811440791
# 0.00818381781605 2 4.92943751152e-10 -0.000461811365255
# 0.0157643938677 2 4.92940700685e-10 -0.000461810956997
# 0.02126406961 2 4.92937278814e-10 -0.000461810499032
# 0.0273920025634 2 4.9293226877e-10 -0.000461809828514
# 0.0289952100974 2 4.92930749761e-10 -0.000461809625218
# 0.0303798802141 2 4.92929368293e-10 -0.00046180944033
# 0.0304378364538 2 4.92929309066e-10 -0.000461809432403
# 0.0326697428031 2 4.92926942343e-10 -0.000461809115653
# 0.0330165269611 2 4.92926559585e-10 -0.000461809064427
# 0.0331119760783 2 4.92926453526e-10 -0.000461809050232
# 0.034197593264 2 4.92925225681e-10 -0.000461808885904
# 0.0352568058035 2 4.92923989527e-10 -0.000461808720464
# 0.03548833314 2 4.92923714302e-10 -0.000461808683629
# 0.0360910595981 2 4.92922989369e-10 -0.000461808586608
# 0.0370670444036 2 4.92921789607e-10 -0.000461808426038
# 0.0376126205325 2 4.92921104991e-10 -0.000461808334412
# 0.0408111963397 2 4.92916890027e-10 -0.000461807770303
# 0.0413432204726 2 4.92916155596e-10 -0.000461807672011
# 0.0441659732083 2 4.92912099814e-10 -0.000461807129205
# 0.0474196757544 2 4.92907092628e-10 -0.000461806459069
# 0.0503548500419 2 4.929022704e-10 -0.000461805813686
# 0.0509408299031 2 4.92901273018e-10 -0.000461805680201
# 0.0542027535475 2 4.92895510076e-10 -0.000461804908917
# 0.0561625165703 2 4.92891875755e-10 -0.000461804422517
# 0.0588557321935 2 4.92886670707e-10 -0.000461803725898
# 0.0606304601393 2 4.9288310754e-10 -0.000461803249021
# -1.04499999975e-06
# 0.00098623787115 2 4.76783552242e-10 -0.000456708467533
# 0.00174901294949 2 4.7678352052e-10 -0.000456708463192
# 0.00387502383268 2 4.76783338729e-10 -0.000456708438316
# 0.00577807713129 2 4.76783059425e-10 -0.000456708400095
# 0.00818381781605 2 4.76782548739e-10 -0.000456708330212
# 0.0157643938677 2 4.76779788574e-10 -0.000456707952505
# 0.02126406961 2 4.7677669235e-10 -0.000456707528811
# 0.0273920025634 2 4.76772159093e-10 -0.00045670690847
# 0.0289952100974 2 4.76770784641e-10 -0.000456706720387
# 0.0303798802141 2 4.76769534643e-10 -0.000456706549334
# 0.0304378364538 2 4.76769481052e-10 -0.000456706542001
# 0.0326697428031 2 4.76767339561e-10 -0.000456706248954
# 0.0330165269611 2 4.76766993229e-10 -0.000456706201561
# 0.0331119760783 2 4.76766897262e-10 -0.000456706188429
# 0.034197593264 2 4.76765786267e-10 -0.000456706036398
# 0.0352568058035 2 4.76764667753e-10 -0.000456705883338
# 0.03548833314 2 4.7676441872e-10 -0.00045670584926
# 0.0360910595981 2 4.76763762776e-10 -0.000456705759499
# 0.0370670444036 2 4.76762677191e-10 -0.000456705610945
# 0.0376126205325 2 4.76762057727e-10 -0.000456705526176
# 0.0408111963397 2 4.76758243884e-10 -0.000456705004281
# 0.0413432204726 2 4.76757579346e-10 -0.000456704913344
# 0.0441659732083 2 4.76753909537e-10 -0.000456704411158
# 0.0474196757544 2 4.76749378864e-10 -0.000456703791169
# 0.0503548500419 2 4.76745015548e-10 -0.000456703194082
# 0.0509408299031 2 4.76744113082e-10 -0.000456703070587
# 0.0542027535475 2 4.76738898576e-10 -0.00045670235702
# 0.0561625165703 2 4.76735610118e-10 -0.000456701907019
# 0.0588557321935 2 4.76730900411e-10 -0.00045670126253
# 0.0606304601393 2 4.76727676336e-10 -0.000456700821338
# -1.02252688161e-06
# 0.00098623787115 2 4.61486426242e-10 -0.000451770933766
# 0.00174901294949 2 4.61486397477e-10 -0.000451770929743
# 0.00387502383268 2 4.61486232628e-10 -0.000451770906689
# 0.00577807713129 2 4.61485979354e-10 -0.000451770871269
# 0.00818381781605 2 4.61485516263e-10 -0.000451770806506
# 0.0157643938677 2 4.61483013336e-10 -0.000451770456473
# 0.02126406961 2 4.6148020567e-10 -0.000451770063821
# 0.0273920025634 2 4.61476094899e-10 -0.000451769488931
# 0.0289952100974 2 4.61474848541e-10 -0.000451769314628
# 0.0303798802141 2 4.61473715039e-10 -0.000451769156108
# 0.0304378364538 2 4.61473666442e-10 -0.000451769149312
# 0.0326697428031 2 4.61471724531e-10 -0.000451768877736
# 0.0330165269611 2 4.61471410476e-10 -0.000451768833816
# 0.0331119760783 2 4.61471323454e-10 -0.000451768821646
# 0.034197593264 2 4.61470316e-10 -0.000451768680753
# 0.0352568058035 2 4.61469301727e-10 -0.000451768538907
# 0.03548833314 2 4.61469075903e-10 -0.000451768507326
# 0.0360910595981 2 4.61468481091e-10 -0.000451768424142
# 0.0370670444036 2 4.61467496679e-10 -0.000451768286472
# 0.0376126205325 2 4.61466934947e-10 -0.000451768207914
# 0.0408111963397 2 4.61463476542e-10 -0.000451767724256
# 0.0413432204726 2 4.61462873936e-10 -0.000451767639982
# 0.0441659732083 2 4.61459546141e-10 -0.00045176717459
# 0.0474196757544 2 4.61455437711e-10 -0.000451766600026
# 0.0503548500419 2 4.6145148104e-10 -0.000451766046685
# 0.0509408299031 2 4.61450662682e-10 -0.000451765932238
# 0.0542027535475 2 4.61445934149e-10 -0.000451765270952
# 0.0561625165703 2 4.61442952163e-10 -0.000451764853921
# 0.0588557321935 2 4.61438681384e-10 -0.000451764256652
# 0.0606304601393 2 4.61435757781e-10 -0.000451763847785
# -1.0009999998e-06
# 0.00098623787115 2 4.46990144074e-10 -0.000446990154527
# 0.00174901294949 2 4.46990117935e-10 -0.000446990150793
# 0.00387502383268 2 4.46989968138e-10 -0.000446990129393
# 0.00577807713129 2 4.46989737989e-10 -0.000446990096515
# 0.00818381781605 2 4.46989317182e-10 -0.000446990036399
# 0.0157643938677 2 4.46987042791e-10 -0.000446989711486
# 0.02126406961 2 4.46984491485e-10 -0.000446989347014
# 0.0273920025634 2 4.46980756056e-10 -0.000446988813381
# 0.0289952100974 2 4.46979623501e-10 -0.000446988651587
# 0.0303798802141 2 4.46978593495e-10 -0.000446988504443
# 0.0304378364538 2 4.46978549336e-10 -0.000446988498135
# 0.0326697428031 2 4.46976784735e-10 -0.000446988246049
# 0.0330165269611 2 4.46976499355e-10 -0.00044698820528
# 0.0331119760783 2 4.46976420279e-10 -0.000446988193983
# 0.034197593264 2 4.46975504812e-10 -0.000446988063202
# 0.0352568058035 2 4.4697458315e-10 -0.000446987931536
# 0.03548833314 2 4.46974377945e-10 -0.000446987902221
# 0.0360910595981 2 4.46973837444e-10 -0.000446987825007
# 0.0370670444036 2 4.46972942915e-10 -0.000446987697217
# 0.0376126205325 2 4.46972432474e-10 -0.000446987624296
# 0.0408111963397 2 4.46969289845e-10 -0.000446987175349
# 0.0413432204726 2 4.46968742262e-10 -0.000446987097122
# 0.0441659732083 2 4.46965718318e-10 -0.000446986665129
# 0.0474196757544 2 4.46961985016e-10 -0.000446986131799
# 0.0503548500419 2 4.46958389617e-10 -0.000446985618169
# 0.0509408299031 2 4.4695764598e-10 -0.000446985511935
# 0.0542027535475 2 4.46953349195e-10 -0.000446984898107
# 0.0561625165703 2 4.46950639485e-10 -0.000446984511004
# 0.0588557321935 2 4.46946758657e-10 -0.000446983956598
# 0.0606304601393 2 4.46944101998e-10 -0.000446983577074

# %%
fig1 = plt.figure(figsize=(12,5))
plt.plot(ms, results[:,0])
plt.grid()
fig1 = plt.figure(figsize=(12,5))
plt.plot(ms, results[:,1])
plt.plot(ms, directgrad)
plt.grid()
fig1 = plt.figure(figsize=(12,5))
plt.plot(ms, results[:,2])
plt.grid()

# %% [markdown]
# ## Soft-abs metric
# The following function implements the soft-abs metric. This makes sure the metric is positive definite and well behaved. I'm not sure yet how to choose `alpha`.

# %%
def softabs(hessians):
    lam, Q = np.linalg.eig(-hessians)
    lam_twig = lam*1./np.tanh(alpha*lam)
    H_twig = np.dot(Q,np.dot(np.diag(lam_twig),Q.T))    
    return H_twig

# %% [markdown]
# ## MCMC loop
# This function is the actual MCMC loop. It can be optimized, but it works. It would probably make sense to have some sort of "state object".

# %%
class State:  
    def __init__(self, thetai, epsiloni):
        self.theta    = thetai
        self.epsilon  = epsiloni
        self.logp, self.gradient, self.hessian = simulation(self.theta)
        self.G        = softabs(self.hessian)
        self.Ginv     = np.linalg.inv(self.G)
        self.Ginvsqrt = np.linalg.cholesky(self.Ginv)    
        self.mu       = self.theta + (self.epsilon)**2 * np.dot(self.Ginv, self.gradient)/2.
        
    def generateProposal(self):
        thetastar = self.mu + (self.epsilon) * np.dot(self.Ginvsqrt, np.random.normal(0.,1.,N_param))
        return State(thetastar,self.epsilon)
    
    def transitionProbability(self,thetaNew):
        return stats.multivariate_normal.logpdf(thetaNew,mean=self.mu, cov=(self.epsilon)**2*self.Ginv)
    
def mcmc(theta,N_steps,epsilon):
    errs = np.zeros(N_steps)
    chain = np.zeros((N_steps,N_param))
    state = State(np.array(theta),epsilon)
    accepted = 0
    print " "
    for i in range(N_steps):
        stateStar = state.generateProposal()
        print " "
        q_ts_t = state.transitionProbability(stateStar.theta)
        q_t_ts = stateStar.transitionProbability(state.theta)
        
        if np.exp(stateStar.logp-state.logp+q_t_ts-q_ts_t) > np.random.uniform():
            accepted += 1
            state = stateStar
        chain[i] = state.theta
        errs[i] = state.logp

    print "Acceptance rate: %.1f%%" % (float(accepted)/float(N_steps)*100.)
    return errs, chain

# %% [markdown]
# ## Run!!
# Let's setup all parameters, create fake observations and run the MCMC

# %%
N_steps                  = 50
alpha                    = 1000.1         # softabs alpha
theta_names              = ["m"]
theta_actual             = [1e-3]
theta_initial            = [1e-3]  # only slightly different, i.e. a pretty good guess

# Generate fake observations and run MCMC
generateObs(theta_actual,data_N=30)
errs, chain = mcmc(theta_initial,N_steps, epsilon=0.75)

# %% [markdown]
# Note the high acceptance rate above!

# %% [markdown]
# ## Plots
# Let's plot the evolution of the chain: logp, and all parameters. Green lines correspond to the actual values used to generate the observations.

# %%
fig1 = plt.figure(figsize=(12,5))
plt.xlabel("iteration"); plt.ylabel("logp");
plt.plot(range(N_steps), errs, color="b");
plt.grid()
for i in range(N_param):
    fig1 = plt.figure(figsize=(12,5))
    plt.xlabel("iteration"); plt.ylabel(theta_names[i]);
    plt.plot(range(N_steps), chain[:,i], color="b");
    plt.plot([0,N_steps-1], [theta_actual[i],theta_actual[i]], color="g");
    plt.grid()

# %% [markdown]
# Autocorrelation plots

# %%
def autocorr(x):
    result = np.correlate(x, x, mode="full")
    return result[result.size/2:]
    
for i in range(N_param):
    fig1 = plt.figure(figsize=(12,5))
    cor = autocorr(chain[:,i]-np.mean(chain[:,i]))
    cor = cor/cor[0]
    plt.xlabel("iteration"); plt.ylabel("autocor("+theta_names[i]+")");
    showSteps = min(300,N_steps)
    half = 0
    for i,c in enumerate(cor):
        if c<0.5:
            half = i
            break
    plt.axvline(half, color="r")
    plt.axhline(0.5, color="r")
    plt.plot(range(N_steps)[:showSteps], cor[:showSteps], color="b");
    plt.xticks(list(plt.xticks()[0])+[half])
    plt.grid()

# %% [markdown]
# Let's make a triangle plot of the distributions. The plot also shows the actual (true) values.

# %%
import triangle
ndim, nsamples = 5, 10000
figure = triangle.corner(chain, labels=theta_names, truths=theta_actual)

# %% [markdown]
# To inspect the evolution, here is a dynamic widget plot, the slider can be used to scan through the iterations and compare the RV curve to the actual observations (only works in an active jupyter notebook).

# %%
from IPython.html.widgets import interact, interactive
from IPython.display import display
times = np.linspace(data_t[0],data_t[-1],500)

def widgetplot(ind):
    fig1 = plt.figure(figsize=(12,5))
    plt.ylabel("radial velocity [m/s]"); plt.xlabel("time [year/(2$\pi$)]")
    plt.errorbar(data_t, data_rv, yerr=data_err, fmt="go")
    plt.plot(times, getRV(theta_actual, times=times), color="g");
    plt.plot(times, getRV(chain[int(ind),:], times=times), color="b");
    plt.grid()

display(interactive(widgetplot, ind=(0,N_steps-1)))

# %% [markdown]
# # Tests

# %%
print results[0]
# Out:
# [ -8.64540522e+01   1.13163136e-01   1.43118901e+04   1.23000000e+00]

# %%
results[:,1]
# Out:
# array([ 0.11316314,  0.07783816,  0.0532846 ,  0.03616974,  0.02422494,
#         0.01589279,  0.01009601,  0.00608432,  0.00333212,  0.00146923,
#         0.00023385, -0.00055986, -0.00104417, -0.00131335, -0.00143467,
#        -0.00145606, -0.00141163, -0.00132555, -0.00121483, -0.00109137])
